# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def fastRandomPointFromDistance(origin, distance, n_dims):
    distance_squared = distance ** 2
    a = np.random.uniform(size=n_dims)
    a /= sum(a)
    a *= distance_squared
    a = np.sqrt(a)
    for i, coord in enumerate(a):
        a[i] *= np.random.choice([1, -1])
    return a

# %%
getRandomCirclePoint(np.asarray([0,0]), 1, 100)
# Out:
# array([ 0.11505476,  0.05176164,  0.05051223, -0.06111396,  0.10975608,
#         0.07833136, -0.09924697,  0.10853163,  0.08397378, -0.0384517 ,
#         0.12353381,  0.08456886,  0.1104899 , -0.09024519, -0.09961585,
#         0.12948813, -0.13565029, -0.06933094,  0.11528091,  0.10327144,
#        -0.10660865, -0.10730515, -0.06633579, -0.09277663,  0.0616273 ,
#         0.11631324,  0.09566728, -0.12850997, -0.10677448,  0.10646156,
#        -0.04784196, -0.12041268,  0.08350182, -0.12840446, -0.06234944,
#         0.10347525,  0.12071797,  0.10950925,  0.13458044, -0.07655763,
#        -0.09917656, -0.10328367,  0.09779874,  0.01258172, -0.114152  ,
#         0.07521792, -0.13324872, -0.13554435,  0.09609325, -0.05624851,
#         0.05320598, -0.12640517,  0.12560847, -0.12923521,  0.12320595,
#        -0.10667902,  0.09224537, -0.06855379,  0.05491948, -0.10974579,
#         0.09407998,  0.06389179, -0.08983655,  0.09164498, -0.01205588,
#         0.12357116, -0.0725268 , -0.09524924,  0.12904678, -0.09475313,
#         0.10328666, -0.09481176, -0.0582875 ,  0.13144735, -0.09928354,
#        -0.07076032,  0.04736991, -0.12685161,  0.13059254,  0.13288414,
#        -0.10183278,  0.04156603,  0.13608837,  0.04403258, -0.11816287,
#         0.05556163, -0.13328942, -0.1045558 ,  0.13131017,  0.03245752,
#         0.11280825, -0.09240597,  0.12788318, -0.03248995, -0.08745239,
#         0.12986461,  0.11633716, -0.12051531, -0.05931278, -0.13376283])

# %%
points = [getRandomCirclePoint(np.asarray([0,0]), 3, 3) for i in range(25)]
pointsx = [point[0] for point in points]
pointsy = [point[1] for point in points]
pointsz = [point[2] for point in points]

fig = plt.figure(figsize=(5, 5))
ax = plt.axes(projection="3d")

ax.scatter3D(pointsx, pointsy, pointsz)
plt.show()
