# %%
# imports
import sys
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    output_path = "/content/drive/My Drive/gan_files"
    # %rm -r /content/BP-Bielko-GAN-Docker
    # %rm -r /content/src
    # !git clone https://github.com/2021-FIIT-Bc-projects/BP-Bielko-GAN-Docker.git
    # %cd BP-Bielko-GAN-Docker/gan
else:
    output_path = "."


from src.dcgan_models import *
# Out:
# 2022-03-07 07:34:17.188846: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-07 07:34:17.188899: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# avatar dataset setup

import  requests, tarfile, time
from clint.textui import progress # remove

dataset_url = "https://storage.googleapis.com/storage/v1/b/cartoonset_public_files/o/cartoonset10k.tgz?alt=media"
dataset_path = "./dataset_download/cartoonset10k"

# %%
r = requests.get(dataset_url, stream=True)
with open(dataset_path + ".tgz", 'wb') as f:
    f.write(r.content)
mkdir(dataset_path)
# !tar zvxfk dataset_download/cartoonset10k.tgz -C dataset_download

# we do this for simplicity of the loader, but csv data is useful for analysis of results
dataset_files = listdir(dataset_path)
for file in dataset_files:
    if file.endswith(".csv"):
        full_path = path.join(dataset_path, file)
        remove(full_path)

# %%
# model definitions

model_name = "dcgan_128_avatar"

p_dims = 100
p_n = 100
predetermined_inputs = np.random.randn(p_dims * p_n)  # n vectors from the normal distribution
predetermined_inputs = predetermined_inputs.reshape(p_n, p_dims)

# %%
height = 128
width = 128

generator = Generator(height, width, n_dim=100, n_paralell_samples=128, init_size=4)
discriminator = Discriminator(height, width, n_filters=128, dataset_path=dataset_path, dataset_type='avatar')

gan = GAN(generator, discriminator, height=height, width=width, model_name=model_name, output_path=output_path)
# Out:
# 2022-03-07 07:34:22.895795: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-07 07:34:22.895854: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-07 07:34:22.895883: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (191f0c32b871): /proc/driver/nvidia/version does not exist
# 2022-03-07 07:34:22.896091: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
open(f'{output_path}/{model_name}/outputs/evaluation/epoch_metadata.txt', 'w').close()
metadata_list = []

# %%
from_epoch = 0
to_epoch = 1

dataset_size = 10000

a = datetime.datetime.now()

gan.train_gan(dataset_size, metadata_list,
              n_dim=100, start_epoch=from_epoch, n_epochs=to_epoch,
              n_batch=dataset_size//700, n_eval=50, eval_samples=100, n_plot=50, plot_size=9)

b = datetime.datetime.now()
print("Time taken: ", b - a)

generator.model.save_weights(f"{output_path}/{model_name}/saves/generator_{to_epoch}.hdf5", overwrite=True)
discriminator.model.save_weights(f"{output_path}/{model_name}/saves/discriminator_{to_epoch}.hdf5", overwrite=True)
# Out:
# [Epoch 0] Batch 0/1428
# 2022-03-07 07:34:24.322811: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# [Epoch 0/1, Batch 0/1428]
#         Time since start: 0:00:15.809662
#         Disc. loss real: 0.7189639806747437
#         Disc. loss fake: 0.6962372064590454
#         Gan loss: 0.692345917224884
#         Acc. real: 1.0
#         Acc. fake: 0.0 (of 100 samples)
# [Epoch 0] Batch 1/1428
# [Epoch 0] Batch 2/1428
# [Epoch 0] Batch 3/1428
# [Epoch 0] Batch 4/1428
# [Epoch 0] Batch 5/1428
# [Epoch 0] Batch 6/1428
# [Epoch 0] Batch 7/1428
# [Epoch 0] Batch 8/1428
# [Epoch 0] Batch 9/1428
# [Epoch 0] Batch 10/1428
# [Epoch 0] Batch 11/1428
# [Epoch 0] Batch 12/1428
# [Epoch 0] Batch 13/1428
# [Epoch 0] Batch 14/1428
# [Epoch 0] Batch 15/1428
# [Epoch 0] Batch 16/1428
# [Epoch 0] Batch 17/1428
# [Epoch 0] Batch 18/1428
# [Epoch 0] Batch 19/1428
# [Epoch 0] Batch 20/1428
# [Epoch 0] Batch 21/1428
# [Epoch 0] Batch 22/1428
# [Epoch 0] Batch 23/1428
# [Epoch 0] Batch 24/1428
# [Epoch 0] Batch 25/1428
# [Epoch 0] Batch 26/1428
# [Epoch 0] Batch 27/1428
# [Epoch 0] Batch 28/1428
# [Epoch 0] Batch 29/1428
# [Epoch 0] Batch 30/1428
# [Epoch 0] Batch 31/1428
# [Epoch 0] Batch 32/1428
# [Epoch 0] Batch 33/1428
# [Epoch 0] Batch 34/1428
# [Epoch 0] Batch 35/1428
# [Epoch 0] Batch 36/1428
# [Epoch 0] Batch 37/1428
# [Epoch 0] Batch 38/1428
# [Epoch 0] Batch 39/1428
# [Epoch 0] Batch 40/1428
# [Epoch 0] Batch 41/1428
# [Epoch 0] Batch 42/1428
# [Epoch 0] Batch 43/1428
# [Epoch 0] Batch 44/1428
# [Epoch 0] Batch 45/1428
# [Epoch 0] Batch 46/1428
# [Epoch 0] Batch 47/1428
# [Epoch 0] Batch 48/1428
# [Epoch 0] Batch 49/1428
# [Epoch 0] Batch 50/1428
# [Epoch 0/1, Batch 50/1428]
#         Time since start: 0:03:03.097004
#         Disc. loss real: 0.042426545172929764
#         Disc. loss fake: 0.4176340699195862
#         Gan loss: 1.3312126398086548
#         Acc. real: 1.0
#         Acc. fake: 1.0 (of 100 samples)
# [Epoch 0] Batch 51/1428
# [Epoch 0] Batch 52/1428
# [Epoch 0] Batch 53/1428
# [Epoch 0] Batch 54/1428
# [Epoch 0] Batch 55/1428
# [Epoch 0] Batch 56/1428
# [Epoch 0] Batch 57/1428
# [Epoch 0] Batch 58/1428
# [Epoch 0] Batch 59/1428
# [Epoch 0] Batch 60/1428
# [Epoch 0] Batch 61/1428
# [Epoch 0] Batch 62/1428
# [Epoch 0] Batch 63/1428
# [Epoch 0] Batch 64/1428
# [Epoch 0] Batch 65/1428
# [Epoch 0] Batch 66/1428
# [Epoch 0] Batch 67/1428
# [Epoch 0] Batch 68/1428
# [Epoch 0] Batch 69/1428
# [Epoch 0] Batch 70/1428
# [Epoch 0] Batch 71/1428
# [Epoch 0] Batch 72/1428
# [Epoch 0] Batch 73/1428
# [Epoch 0] Batch 74/1428
# [Epoch 0] Batch 75/1428
# [Epoch 0] Batch 76/1428
# [Epoch 0] Batch 77/1428
# [Epoch 0] Batch 78/1428
# [Epoch 0] Batch 79/1428
# [Epoch 0] Batch 80/1428
# [Epoch 0] Batch 81/1428
# [Epoch 0] Batch 82/1428
# [Epoch 0] Batch 83/1428
# [Epoch 0] Batch 84/1428
# [Epoch 0] Batch 85/1428
# [Epoch 0] Batch 86/1428
# [Epoch 0] Batch 87/1428
# [Epoch 0] Batch 88/1428
# [Epoch 0] Batch 89/1428
# [Epoch 0] Batch 90/1428
# [Epoch 0] Batch 91/1428
# [Epoch 0] Batch 92/1428
# [Epoch 0] Batch 93/1428
# [Epoch 0] Batch 94/1428
# [Epoch 0] Batch 95/1428
# [Epoch 0] Batch 96/1428
# [Epoch 0] Batch 97/1428
# [Epoch 0] Batch 98/1428
# [Epoch 0] Batch 99/1428
# [Epoch 0] Batch 100/1428
# [Epoch 0/1, Batch 100/1428]
#         Time since start: 0:05:51.003333
#         Disc. loss real: 0.47316640615463257
#         Disc. loss fake: 0.10263095051050186
#         Gan loss: 3.1261346340179443
#         Acc. real: 0.9800000190734863
#         Acc. fake: 1.0 (of 100 samples)
# [Epoch 0] Batch 101/1428
# [Epoch 0] Batch 102/1428
# [Epoch 0] Batch 103/1428
# [Epoch 0] Batch 104/1428
# [Epoch 0] Batch 105/1428
# [Epoch 0] Batch 106/1428
# [Epoch 0] Batch 107/1428
# [Epoch 0] Batch 108/1428
# [Epoch 0] Batch 109/1428
# [Epoch 0] Batch 110/1428
# [Epoch 0] Batch 111/1428
# [Epoch 0] Batch 112/1428
# [Epoch 0] Batch 113/1428
# [Epoch 0] Batch 114/1428
# [Epoch 0] Batch 115/1428
# [Epoch 0] Batch 116/1428
# [Epoch 0] Batch 117/1428
# [Epoch 0] Batch 118/1428
# [Epoch 0] Batch 119/1428
# [Epoch 0] Batch 120/1428
# [Epoch 0] Batch 121/1428
# [Epoch 0] Batch 122/1428
# [Epoch 0] Batch 123/1428
# [Epoch 0] Batch 124/1428
# [Epoch 0] Batch 125/1428
# [Epoch 0] Batch 126/1428
# [Epoch 0] Batch 127/1428
# [Epoch 0] Batch 128/1428
# [Epoch 0] Batch 129/1428
# [Epoch 0] Batch 130/1428
# [Epoch 0] Batch 131/1428
# [Epoch 0] Batch 132/1428
# [Epoch 0] Batch 133/1428
# [Epoch 0] Batch 134/1428
# [Epoch 0] Batch 135/1428
# [Epoch 0] Batch 136/1428
